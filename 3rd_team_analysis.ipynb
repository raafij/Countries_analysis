# %% [markdown]
# <h1>Introduction</h1>
#
# <p>We have analyzed the following countries from Eastern Europe

# %%
# Importing packages

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# File directory
dataset_file = "./Final_Project_Dataset.xlsx"

european_countries = "./european_countries.xlsx"

data = pd.read_excel(io = dataset_file,
                   sheet_name = "Data",
                   header = 0)
# Out:
#   File "<ipython-input-1-09af6e4ea5bd>", line 17
#     sheet_name = "European_countries",
#     ^
# IndentationError: unexpected indent

# %%
eu = []
for i in range(len(european_countries_list)):
    eu.append(european_countries_list.iloc[i,0])
    print(eu)
# Out:
# ['Austria']
# ['Austria', 'Belgium']
# ['Austria', 'Belgium', 'Czechia']
# ['Austria', 'Belgium', 'Czechia', 'Denmark']
# ['Austria', 'Belgium', 'Czechia', 'Denmark', 'Estonia']
# ['Austria', 'Belgium', 'Czechia', 'Denmark', 'Estonia', 'Finland']
# ['Austria', 'Belgium', 'Czechia', 'Denmark', 'Estonia', 'Finland', 'France']
# ['Austria', 'Belgium', 'Czechia', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany']
# ['Austria', 'Belgium', 'Czechia', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece']
# ['Austria', 'Belgium', 'Czechia', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary']
# ['Austria', 'Belgium', 'Czechia', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland']
# ['Austria', 'Belgium', 'Czechia', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland', 'Italy']
# ...

# %%
data = data[data["Cool Name"] == "Skids & Mudflap"]

# %%
data
# Out:
#     Country Code Total            Country Name     Hult Region  \
# 3                  ALB                 Albania  Eastern Europe
# 4                  AND                 Andorra  Eastern Europe
# 21                 BIH  Bosnia and Herzegovina  Eastern Europe
# 48                 CZE          Czech Republic  Eastern Europe
# 59                 EST                 Estonia  Eastern Europe
# 61                 FIN                 Finland  Eastern Europe
# 75                 GRC                  Greece  Eastern Europe
# 83                 HRV                 Croatia  Eastern Europe
# 85                 HUN                 Hungary  Eastern Europe
# 114                LTU               Lithuania  Eastern Europe
# 116                LVA                  Latvia  Eastern Europe
# 126                MKD          Macedonia, FYR  Eastern Europe
# 128                MLT                   Malta  Eastern Europe
# 130                MNE              Montenegro  Eastern Europe
# ...

# %%
data["EU"] = data['Country Name'].apply(lambda x: any([k in x for k in eu]))
